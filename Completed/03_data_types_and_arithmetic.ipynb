# %% [markdown]
# <a href="https://colab.research.google.com/github/jtsui23-code/Jtsui23-code-DataScience-2025/blob/main/Completed/03_data_types_and_arithmetic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 03 - Data Types and Arithmetic
#
# Explore Python basics like variables, data types, and arithmetic operations.

# %% [markdown]
# ## ✅ Learning Goals
# - Understand Python data types
# - Use variables and print statements
# - Perform basic arithmetic

# %%
# 🧠 Variables and Types
x = 10
y = 3.5
z = 'hello'
print(type(x), type(y), type(z))

# %%
# ➕ Arithmetic Operations
print('Add:', x + y)
print('Divide:', x / y)
print('Floor Divide:', x // y)
print('Exponent:', x ** 2)

# %% [markdown]
# ## ✏️ Try It Yourself
# - Create your own variables
# - Try combining numbers and strings
# - Use `input()` to interact

# %%
# Your code here
name = input('What is your name? ')
print('Welcome,', name)
age = int(input('How old are you?'))
print(f'{name} you are {age} years old')
print(f'age variable is a {type(age)} variable while name is a {type(name)}')
# Out:
# What is your name? bob
# Welcome, bob
# How old are you?23
# bob you are 23 years old
# age variable is a <class 'int'> variable while name is a <class 'str'>

# %% [markdown]
# ## 📤 Submit
# Make sure your name is at the top in a Markdown cell.
# Submit via D2L or Colab link.
