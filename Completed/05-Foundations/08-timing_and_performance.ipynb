# %% [markdown]
# <a href="https://colab.research.google.com/github/jtsui23-code/Jtsui23-code-DataScience-2025/blob/main/Completed/05-Foundations/08-timing_and_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⏱️ 08 - Timing and Performance
#
# In data science, performance matters. Some code runs fast, some slow.
# Jupyter/IPython gives us tools to measure runtime easily.
#
# In this notebook you will learn:
# - `%time` and `%timeit` for single expressions
# - `%%time` and `%%timeit` for entire cells
# - Comparing loops, list comprehensions, and NumPy
# - Why performance awareness is important

# %% [markdown]
# ## 1. `%time`

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: user 37.6 ms, sys: 0 ns, total: 37.6 ms
# Wall time: 51.4 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Use `%time` to measure how long it takes to sort a list of 1 million random numbers.

# %%
import random

array = []
for i in array:
  array.append(random.randint(1, 1000000))

# %time array.sort()
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.68 µs

# %% [markdown]
# ## 2. `%timeit`

# %%
numbers = list(range(1_000))
# %timeit [x**2 for x in numbers]

# %% [markdown]
# ✅ **Your Turn**: Compare `%timeit` results for a list comprehension vs. a `for` loop that builds the same list.

# %%
numbers = list(range(2000))
cubed = []
# %timeit [x**3 for x in numbers]

# %timeit for x in numbers: cubed.append(x**3)
# Out:
# 177 µs ± 38 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 228 µs ± 35.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ## 3. `%%time` for a Whole Cell

# %%
# %%time
total = 0
for i in range(1_000_000):
    total += i
total
# Out:
# CPU times: user 137 ms, sys: 0 ns, total: 137 ms
# Wall time: 137 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Wrap a longer multi-line operation with `%%time` to measure its runtime.

# %%
# %%time
n, m = 2000, 1000
array = [[0]*m for _ in range(n)]
for i in range(2000):
  for j in range(1000):
    array[i][j] = i * j
# Out:
# CPU times: user 273 ms, sys: 37.9 ms, total: 311 ms
# Wall time: 313 ms

# %% [markdown]
# ## 4. Comparing Loops vs. NumPy

# %%
import numpy as np

numbers = np.arange(1_000_000)

# Python loop
# %timeit [x**2 for x in numbers]

# NumPy vectorized
# %timeit numbers**2
# Out:
# 276 ms ± 55.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.29 ms ± 58.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Try squaring numbers with a Python loop, list comprehension, and NumPy array. Compare times.

# %%
import numpy as np
cap = np.arange(100)

# %timeit [x**2 for x in cap]
print("")
# %timeit cap**2
# Out:
# 16.7 µs ± 4.69 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)
#
# 693 ns ± 7.01 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## 5. Why This Matters
# - Performance differences become huge with large datasets.
# - Vectorized operations (like NumPy, Pandas) are usually faster.
# - `%timeit` is your friend when deciding how to implement something.

# %% [markdown]
# ---
# ### Summary
# - `%time` and `%timeit` measure execution speed.
# - `%%time` and `%%timeit` work on whole cells.
# - Loops are slower than list comprehensions, which are slower than NumPy.
# - Always measure performance before optimizing.
